# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
import requests

# %%
def load_data(file_path, url_path):
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
    else:
        d,i,offset_size = [],0,100000
        k = offset_size
        while k == offset_size:
            if i > 10:
                break
            r=requests.get(
                url = url_path, 
                params={
                    '$limit':offset_size, 
                    '$offset':offset_size*i
                }
            )
    
            as_df = pd.DataFrame(r.json())
            k = len(as_df)
            i += 1
            d.append(as_df)
    
        df = pd.concat(d)
        df.to_csv(file_path)
        df.head(10)
    return df

# %%
tree_census_df =load_data('tree_census/flatfiles/tree_census_15.csv', 'https://data.cityofnewyork.us/resource/5rq2-4hqu.json')

# %%
air_quality_df = load_data('data/Air_Quality_20241206.csv', 'https://data.cityofnewyork.us/resource/c3uy-2p5r.json')

# %%
green_streets_df = load_data('data/Greenstreets.csv', 'https://data.cityofnewyork.us/resource/mk9u-qu7i.json')

# %%
property_valuation_df = load_data('data/Property_Valuation_and_Assessment_Data_20241125.csv', 'https://data.cityofnewyork.us/resource/yjxr-fw8i.json')

# %% [markdown]
# # Tree Census Data Sanitation

# %%
cols = [
    'tree_id','block_id','the_geom','zipcode','cb_num','borocode','nta_name',
    'health','status','tree_dbh','spc_common','spc_latin','problems','sidewalk',
]

tree_census_tr = tree_census_df[cols]
tree_census_tr = tree_census_tr.loc[tree_census_df['status']=='Alive']
tree_census_tr = tree_census_tr.loc[~tree_census_tr['health'].isna()]
tree_census_tr['tree_dbh'] = tree_census_tr['tree_dbh'].astype(int)

tree_census_tr.head()
# Out:
#    tree_id  block_id                                           the_geom  \
# 0   180683    348711  {'type': 'Point', 'coordinates': [-73.84421521...
# 1   200540    315986  {'type': 'Point', 'coordinates': [-73.81867945...
# 2   204026    218365  {'type': 'Point', 'coordinates': [-73.93660770...
# 3   204337    217969  {'type': 'Point', 'coordinates': [-73.93445615...
# 4   189565    223043  {'type': 'Point', 'coordinates': [-73.97597938...
#
#    zipcode  cb_num  borocode            nta_name health status  tree_dbh  \
# 0    11375     406         4        Forest Hills   Fair  Alive         3
# 1    11357     407         4          Whitestone   Fair  Alive        21
# 2    11211     301         3   East Williamsburg   Good  Alive         3
# 3    11211     301         3   East Williamsburg   Good  Alive        10
# 4    11215     306         3  Park Slope-Gowanus   Good  Alive        21
#
#         spc_common                           spc_latin problems  sidewalk
# 0        red maple                         Acer rubrum      NaN  NoDamage
# 1          pin oak                   Quercus palustris   Stones    Damage
# 2      honeylocust  Gleditsia triacanthos var. inermis      NaN    Damage
# 3      honeylocust  Gleditsia triacanthos var. inermis   Stones    Damage
# 4  American linden                     Tilia americana   Stones    Damage

# %%
#make analysis at zipcode level...
cb_grp = tree_census_tr.groupby(['cb_num']).agg(
    tree_count=('tree_id', len), 
    tree_size=('tree_dbh', np.sum)
)

#avg tree size (diameter)
cb_grp['tree_size'] = cb_grp['tree_size']/cb_grp['tree_count']

#count trees per zip/health category (good, fair, bad), then pivot on the health cats
cb_grp_health_status = tree_census_tr.groupby(['cb_num','health'])[['tree_id']].count().reset_index()
cb_grp_health_status_piv = cb_grp_health_status.pivot(
    index='cb_num',
    columns='health', 
    values='tree_id'
)

#concat cb features
cb_grp_health_status_piv = cb_grp_health_status_piv.div(cb_grp['tree_count'], axis=0)
tree_cb_features = pd.concat((cb_grp_health_status_piv,cb_grp),axis=1)

tree_cb_features['Good'] = tree_cb_features['Good'].fillna(0.0)
tree_cb_features = tree_cb_features.rename(
    columns={
        'Good':'Tree Quality'
    }
)

tree_cb_features = tree_cb_features.reset_index()
tree_cb_features['cb_num'] = tree_cb_features['cb_num'].astype(str)
tree_cb_features = tree_cb_features[['cb_num', 'Tree Quality', 'tree_count']]
tree_cb_features.head()
# Out:
# /var/folders/wx/wz1pbs1903j_cfgqws400dz80000gn/T/ipykernel_70401/1516815439.py:2: FutureWarning: The provided callable <function sum at 0x11859a8b0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   cb_grp = tree_census_tr.groupby(['cb_num']).agg(
#   cb_num  Tree Quality  tree_count
# 0    101      0.764040        2297
# 1    102      0.730602        4833
# 2    103      0.764069        4709
# 3    104      0.824395        4419
# 4    105      0.673560        2031

# %%
cb_geometries = gpd.read_file("tree_census/flatfiles/Community Districts.geojson")
geo_cols = ['boro_cd','shape_area','geometry']
cb_geometries = cb_geometries[geo_cols].rename(
    columns={
        'boro_cd':'cb_num'
    }
)
tree_census_geoms = tree_cb_features.merge(
    cb_geometries, 
    how='inner', 
    on='cb_num'
)

tree_census_geoms['cb_acreage'] = tree_census_geoms['shape_area'].astype(np.float64)/43560
tree_census_geoms['Tree Density (per Acre)'] = tree_census_geoms['tree_count']/tree_census_geoms['cb_acreage']

tree_census_geoms.head()
# Out:
#   cb_num  Tree Quality  tree_count     shape_area  \
# 0    101      0.764040        2297   41692711.732
# 1    102      0.730602        4833  37724014.4661
# 2    103      0.764069        4709  46879905.4307
# 3    104      0.824395        4419  49310051.9139
# 4    105      0.673560        2031   43790039.865
#
#                                             geometry   cb_acreage  \
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...   957.132960
# 1  MULTIPOLYGON (((-74.00915 40.7425, -74.00902 4...   866.024207
# 2  MULTIPOLYGON (((-73.98878 40.73397, -73.98757 ...  1076.214542
# 3  MULTIPOLYGON (((-73.99394 40.77318, -73.9937 4...  1132.003028
# 4  MULTIPOLYGON (((-73.97301 40.76428, -73.97141 ...  1005.280989
#
#    Tree Density (per Acre)
# 0                 2.399876
# 1                 5.580675
# 2                 4.375522
# 3                 3.903700
# 4                 2.020331

# %% [markdown]
# # Air Quality Data Sanitation

# %%
air_quality_df.head()
# Out:
#    Unnamed: 0  unique_id  indicator_id                    name measure  \
# 0           0     827080           386              Ozone (O3)    Mean
# 1           1     827061           386              Ozone (O3)    Mean
# 2           2     827067           386              Ozone (O3)    Mean
# 3           3     827081           386              Ozone (O3)    Mean
# 4           4     825967           375  Nitrogen dioxide (NO2)    Mean
#
#   measure_info geo_type_name  geo_join_id  \
# 0          ppb         UHF34        104.0
# 1          ppb         UHF34        405.0
# 2          ppb         UHF34        302.0
# 3          ppb         UHF34        103.0
# 4          ppb         UHF34        104.0
#
#                          geo_place_name  time_period               start_date  \
# 0                  Pelham - Throgs Neck  Summer 2022  2022-06-01T00:00:00.000
# 1              Ridgewood - Forest Hills  Summer 2022  2022-06-01T00:00:00.000
# 2  Central Harlem - Morningside Heights  Summer 2022  2022-06-01T00:00:00.000
# 3                    Fordham - Bronx Pk  Summer 2022  2022-06-01T00:00:00.000
# 4                  Pelham - Throgs Neck  Summer 2022  2022-06-01T00:00:00.000
#
#    data_value
# 0        33.3
# 1        34.2
# 2        30.9
# 3        31.7
# 4        12.0

# %%
air_quality_df = air_quality_df.dropna(subset=['geo_join_id'])

# %%
air_quality_df['geo_join_id'] = air_quality_df['geo_join_id'].astype('int64')

# %%
air_quality_df['name'].unique()
# Out:
# array(['Ozone (O3)', 'Nitrogen dioxide (NO2)', 'Fine particles (PM 2.5)',
#        'Annual vehicle miles traveled (cars)',
#        'Annual vehicle miles traveled (trucks)',
#        'Annual vehicle miles traveled',
#        'Respiratory hospitalizations due to PM2.5 (age 20+)',
#        'Asthma emergency department visits due to PM2.5',
#        'Asthma emergency departments visits due to Ozone',
#        'Cardiovascular hospitalizations due to PM2.5 (age 40+)',
#        'Cardiac and respiratory deaths due to Ozone',
#        'Asthma hospitalizations due to Ozone', 'Deaths due to PM2.5',
#        'Boiler Emissions- Total PM2.5 Emissions',
#        'Boiler Emissions- Total SO2 Emissions',
#        'Boiler Emissions- Total NOx Emissions',
#        'Outdoor Air Toxics - Formaldehyde',
#        'Outdoor Air Toxics - Benzene'], dtype=object)

# %%
air_quality_df = air_quality_df[air_quality_df['name'].str.contains('Outdoor Air Toxics') | air_quality_df['name'].str.contains('Boiler Emissions') ]

# %%
simplified_tree_df = tree_census_df[['the_geom', 'zipcode', 'zip_city', 'cb_num', 'borocode', 'boroname', 'boro_ct', 'state']]

# %%
simplified_tree_df = simplified_tree_df[(simplified_tree_df['zipcode'] >= 10000) & (simplified_tree_df['zipcode']<11500)]
simplified_tree_df = simplified_tree_df.rename(columns={'the_geom': 'geometry', 'oldName2': 'newName2'})

# %%
simplified_tree_df.shape
# Out:
# (670351, 8)

# %%
simplified_tree_df = simplified_tree_df.drop_duplicates(subset=['cb_num'])

# %%
simplified_tree_df.shape
# Out:
# (59, 8)

# %%
air_quality_geo_df =  air_quality_df.merge(simplified_tree_df, left_on='geo_join_id', right_on='cb_num')

# %%
air_quality_geo_df.head()
# Out:
#    Unnamed: 0  unique_id  indicator_id  \
# 0        8151     179825           641
# 1        8157     179783           640
# 2        8158     179773           640
# 3        8159     179722           642
# 4        8160     179792           640
#
#                                       name         measure measure_info  \
# 0  Boiler Emissions- Total PM2.5 Emissions  Number per km2       number
# 1    Boiler Emissions- Total SO2 Emissions  Number per km2       number
# 2    Boiler Emissions- Total SO2 Emissions  Number per km2       number
# 3    Boiler Emissions- Total NOx Emissions  Number per km2       number
# 4    Boiler Emissions- Total SO2 Emissions  Number per km2       number
#
#   geo_type_name  geo_join_id         geo_place_name time_period  \
# 0         UHF42          406          Fresh Meadows        2015
# 1         UHF42          104   Pelham - Throgs Neck        2015
# 2         UHF42          404  Bayside - Little Neck        2015
# 3         UHF42          410              Rockaways        2015
# 4         UHF42          206           Borough Park        2015
#
#                 start_date  data_value  \
# 0  2015-01-01T00:00:00.000         0.4
# 1  2015-01-01T00:00:00.000         2.8
# 2  2015-01-01T00:00:00.000         0.9
# 3  2015-01-01T00:00:00.000         6.1
# 4  2015-01-01T00:00:00.000         1.1
#
#                                             the_geom  zipcode      zip_city  \
# 0  {'type': 'Point', 'coordinates': [-73.84421521...    11375  Forest Hills
# 1  {'type': 'Point', 'coordinates': [-73.98729652...    10019      New York
# 2  {'type': 'Point', 'coordinates': [-73.86529991...    11373      Elmhurst
# 3  {'type': 'Point', 'coordinates': [-73.84344476...    11414  Howard Beach
# 4  {'type': 'Point', 'coordinates': [-73.89338225...    10457         Bronx
#
#    cb_num  borocode   boroname  boro_ct     state
# 0     406         4     Queens  4073900  New York
# 1     104         1  Manhattan  1012700  New York
# 2     404         4     Queens  4044302  New York
# 3     410         4     Queens  4089200  New York
# 4     206         2      Bronx  2037504  New York

# %% [markdown]
# # Green Streets Data Sanitation

# %%
green_streets_df.shape
# Out:
# (2753, 26)

# %% [markdown]
# # Property Valuation Data Sanitation

# %%
property_valuation_df.shape
# Out:
# (1100000, 45)
