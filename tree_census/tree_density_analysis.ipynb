# %% [markdown]
# ### NYC Tree Census Pre-processing + EDA

# %%
import requests
import pandas as pd 
import numpy as np
import os 

file_path = 'flatfiles/tree_census_15.csv'
if os.path.exists(file_path):
    tree_census_df = pd.read_csv(file_path)
else:
    tree_census_url = 'https://data.cityofnewyork.us/resource/5rq2-4hqu.json'
    d,i,offset_size = [],0,100000
    k = offset_size
    while k == offset_size:
        if i > 10:
            break
        r=requests.get(
            url = tree_census_url, 
            params={
                '$limit':offset_size, 
                '$offset':offset_size*i
            }
        )

        as_df = pd.DataFrame(r.json())
        k = len(as_df)
        i += 1
        d.append(as_df)

    tree_census_df = pd.concat(d)
    tree_census_df.to_csv(file_path)
    tree_census_df.head(10)

# %%
os.path.exists('tree_census/flatfiles/tree_features_final.csv')
os.path.abspath(os.getcwd())
# Out:
# '/Users/devenbarth/I2ADS-2024-group-project/tree_census'

# %%
tree_census_df.columns
# Out:
# Index(['Unnamed: 0', 'created_at', 'tree_id', 'block_id', 'the_geom',
#        'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin',
#        'spc_common', 'steward', 'guards', 'sidewalk', 'user_type', 'problems',
#        'root_stone', 'root_grate', 'root_other', 'trnk_wire', 'trnk_light',
#        'trnk_other', 'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address',
#        'zipcode', 'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
np.sort(tree_census_df['nta'].unique())
# Out:
# array(['BK09', 'BK17', 'BK19', 'BK21', 'BK23', 'BK25', 'BK26', 'BK27',
#        'BK28', 'BK29', 'BK30', 'BK31', 'BK32', 'BK33', 'BK34', 'BK35',
#        'BK37', 'BK38', 'BK40', 'BK41', 'BK42', 'BK43', 'BK44', 'BK45',
#        'BK46', 'BK50', 'BK58', 'BK60', 'BK61', 'BK63', 'BK64', 'BK68',
#        'BK69', 'BK72', 'BK73', 'BK75', 'BK76', 'BK77', 'BK78', 'BK79',
#        'BK81', 'BK82', 'BK83', 'BK85', 'BK88', 'BK90', 'BK91', 'BK93',
#        'BK95', 'BK96', 'BX01', 'BX03', 'BX05', 'BX06', 'BX07', 'BX08',
#        'BX09', 'BX10', 'BX13', 'BX14', 'BX17', 'BX22', 'BX26', 'BX27',
#        'BX28', 'BX29', 'BX30', 'BX31', 'BX33', 'BX34', 'BX35', 'BX36',
#        'BX37', 'BX39', 'BX40', 'BX41', 'BX43', 'BX44', 'BX46', 'BX49',
#        'BX52', 'BX55', 'BX59', 'BX62', 'BX63', 'BX75', 'MN01', 'MN03',
#        'MN04', 'MN06', 'MN09', 'MN11', 'MN12', 'MN13', 'MN14', 'MN15',
#        'MN17', 'MN19', 'MN20', 'MN21', 'MN22', 'MN23', 'MN24', 'MN25',
#        'MN27', 'MN28', 'MN31', 'MN32', 'MN33', 'MN34', 'MN35', 'MN36',
#        'MN40', 'MN50', 'QN01', 'QN02', 'QN03', 'QN05', 'QN06', 'QN07',
#        'QN08', 'QN10', 'QN12', 'QN15', 'QN17', 'QN18', 'QN19', 'QN20',
#        'QN21', 'QN22', 'QN23', 'QN25', 'QN26', 'QN27', 'QN28', 'QN29',
#        'QN30', 'QN31', 'QN33', 'QN34', 'QN35', 'QN37', 'QN38', 'QN41',
#        'QN42', 'QN43', 'QN44', 'QN45', 'QN46', 'QN47', 'QN48', 'QN49',
#        'QN50', 'QN51', 'QN52', 'QN53', 'QN54', 'QN55', 'QN56', 'QN57',
#        'QN60', 'QN61', 'QN62', 'QN63', 'QN66', 'QN68', 'QN70', 'QN71',
#        'QN72', 'QN76', 'SI01', 'SI05', 'SI07', 'SI08', 'SI11', 'SI12',
#        'SI14', 'SI22', 'SI24', 'SI25', 'SI28', 'SI32', 'SI35', 'SI36',
#        'SI37', 'SI45', 'SI48', 'SI54'], dtype=object)

# %%
#### only look at trees that are alive 
cols = [
    'tree_id','block_id','the_geom','zipcode','cb_num','borocode','nta_name',
    'health','status','tree_dbh','spc_common','spc_latin','problems','sidewalk',
]

tree_census_tr = tree_census_df[cols]
tree_census_tr = tree_census_tr.loc[tree_census_df['status']=='Alive']
tree_census_tr.loc[tree_census_tr.isna().any(axis=1)]

tree_census_tr = tree_census_tr.loc[~tree_census_tr['health'].isna()]
tree_census_tr['tree_dbh'] = tree_census_tr['tree_dbh'].astype(int)
tree_census_tr
# Out:
#         tree_id  block_id                                           the_geom  \
# 0        180683    348711  {'type': 'Point', 'coordinates': [-73.84421521...
# 1        200540    315986  {'type': 'Point', 'coordinates': [-73.81867945...
# 2        204026    218365  {'type': 'Point', 'coordinates': [-73.93660770...
# 3        204337    217969  {'type': 'Point', 'coordinates': [-73.93445615...
# 4        189565    223043  {'type': 'Point', 'coordinates': [-73.97597938...
# ...         ...       ...                                                ...
# 683783   155433    217978  {'type': 'Point', 'coordinates': [-73.95494401...
# 683784   183795    348185  {'type': 'Point', 'coordinates': [-73.85665019...
# 683785   166161    401670  {'type': 'Point', 'coordinates': [-74.13651724...
# 683786   184028    504204  {'type': 'Point', 'coordinates': [-73.90311472...
# 683787   200607    306527  {'type': 'Point', 'coordinates': [-73.78752645...
#
#         zipcode  cb_num  borocode               nta_name health status  \
# 0         11375     406         4           Forest Hills   Fair  Alive
# 1         11357     407         4             Whitestone   Fair  Alive
# 2         11211     301         3      East Williamsburg   Good  Alive
# 3         11211     301         3      East Williamsburg   Good  Alive
# 4         11215     306         3     Park Slope-Gowanus   Good  Alive
# ...         ...     ...       ...                    ...    ...    ...
# 683783    11211     301         3  North Side-South Side   Good  Alive
# 683784    11375     406         4           Forest Hills   Good  Alive
# 683785    10314     501         5            Westerleigh   Good  Alive
# 683786    10457     205         2             Mount Hope   Good  Alive
# 683787    11365     408         4   Fresh Meadows-Utopia   Fair  Alive
#
#         tree_dbh           spc_common                           spc_latin  \
# 0              3            red maple                         Acer rubrum
# 1             21              pin oak                   Quercus palustris
# 2              3          honeylocust  Gleditsia triacanthos var. inermis
# 3             10          honeylocust  Gleditsia triacanthos var. inermis
# 4             21      American linden                     Tilia americana
# ...          ...                  ...                                 ...
# 683783        25              pin oak                   Quercus palustris
# 683784         7  Kentucky yellowwood                 Cladrastis kentukea
# 683785        12            red maple                         Acer rubrum
# 683786         9            red maple                         Acer rubrum
# 683787        23            red maple                         Acer rubrum
#
#        problems  sidewalk
# 0           NaN  NoDamage
# 1        Stones    Damage
# 2           NaN    Damage
# 3        Stones    Damage
# 4        Stones    Damage
# ...         ...       ...
# 683783      NaN    Damage
# 683784      NaN  NoDamage
# 683785      NaN    Damage
# 683786      NaN  NoDamage
# 683787      NaN  NoDamage
#
# [652172 rows x 14 columns]

# %%
tree_census_tr[['zipcode','cb_num']].drop_duplicates().sort_values(by=['cb_num']).head(10)
# Out:
#        zipcode  cb_num
# 24096    10013     101
# 92555    10006     101
# 73499    10282     101
# 66793    10281     101
# 262      10048     101
# 10526    10004     101
# 12626    10007     101
# 5789     10005     101
# 1441     10038     101
# 445      10280     101

# %%
import numpy as np

#make analysis at zipcode level...
zipcode_grp = tree_census_tr.groupby(['zipcode']).agg(
    tree_count=('tree_id', len), 
    tree_size=('tree_dbh', np.sum)
)

#avg tree size (diameter)
zipcode_grp['tree_size'] = zipcode_grp['tree_size']/zipcode_grp['tree_count']

#count trees per zip/health category (good, fair, bad), then pivot on the health cats
zipcode_grp_health_status = tree_census_tr.groupby(['zipcode','health'])[['tree_id']].count().reset_index()
zipcode_grp_health_status_piv = zipcode_grp_health_status.pivot(
    index='zipcode',
    columns='health', 
    values='tree_id'
)

#concat zip features
zipcode_grp_health_status_piv = zipcode_grp_health_status_piv.div(zipcode_grp['tree_count'], axis=0)
tree_zip_features = pd.concat((zipcode_grp_health_status_piv,zipcode_grp),axis=1)
tree_zip_features
# Out:
# /var/folders/wx/wz1pbs1903j_cfgqws400dz80000gn/T/ipykernel_73199/2345899268.py:4: FutureWarning: The provided callable <function sum at 0x107e1ab80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   zipcode_grp = tree_census_tr.groupby(['zipcode']).agg(
#              Fair      Good      Poor  tree_count  tree_size
# zipcode
# 83       0.041845  0.949571  0.008584         932  16.505365
# 10001    0.117647  0.845882  0.036471         850   7.365882
# 10002    0.179333  0.767377  0.053290        2158   8.459222
# 10003    0.185795  0.761709  0.052496        1943   9.077200
# 10004    0.145299  0.829060  0.025641         117   6.658120
# ...           ...       ...       ...         ...        ...
# 11691    0.234614  0.701417  0.063969        5362   8.813316
# 11692    0.280730  0.602254  0.117016        1863   4.962963
# 11693    0.284304  0.511352  0.204344        1013   7.897335
# 11694    0.262280  0.616499  0.121222        3176   8.053841
# 11697    0.333333       NaN  0.666667          24   4.666667
#
# [191 rows x 5 columns]

# %%
tree_census_df['spc_common'].value_counts()
# Out:
# spc_common
# London planetree    87014
# honeylocust         64264
# Callery pear        58931
# pin oak             53185
# Norway maple        34189
#                     ...
# black pine             37
# pitch pine             33
# Osage-orange           29
# Scots pine             25
# Virginia pine          10
# Name: count, Length: 132, dtype: int64

# %%
import geopandas as gpd
import warnings 
warnings.filterwarnings('ignore')

#read zip geometry file
zips = gpd.read_file('flatfiles/ZIP_CODE_040114.shp')
zips.head(10)

#get population, area info per zip, to build per-capita feats wrto the tree data 
zips_tr = zips[[
    'ZIPCODE','POPULATION','AREA','geometry'
]]
zips_tr['ZIPCODE'] = zips_tr['ZIPCODE'].astype(np.int64)

#merge zip feats w tree feats
tree_zip_features = tree_zip_features.reset_index()
tree_zip_features_m = tree_zip_features.merge(
    zips_tr, 
    how='inner', 
    left_on='zipcode', 
    right_on='ZIPCODE', 
)

#build feats bridging zip attributes w tree quality/quantity (trees per unit area, trees per person, etc.)
tree_zip_features_m = tree_zip_features_m.set_index('zipcode')
tree_zip_features_m = tree_zip_features_m.loc[tree_zip_features_m['POPULATION']>0]
tree_zip_features_m['trees_per_ppl'] = tree_zip_features_m['tree_count']/tree_zip_features_m['POPULATION']
tree_zip_features_m['acres_ttl'] = tree_zip_features_m['AREA']/43560
tree_zip_features_m['tree_density (per acre)'] = tree_zip_features_m['tree_count']/tree_zip_features_m['acres_ttl']
tree_zip_features_m['Good'] = tree_zip_features_m['Good'].fillna(0.0)
tree_zip_features_m = tree_zip_features_m.rename(
    columns={
        'Good':'Tree Quality'
    }
)
#tree_zip_features_m['Poor'] = tree_zip_features_m['Poor'].fillna(0.0)
tree_zip_features_m = tree_zip_features_m.drop(
    columns=[
        'ZIPCODE','POPULATION',
    ]
)

#get important features
tree_features = [
    'Tree Quality', 'trees_per_ppl', 'tree_density (per acre)', 'geometry'
]
tree_zip_features_trunc = gpd.GeoDataFrame(tree_zip_features_m[tree_features])
tree_zip_features_trunc
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[9], line 6
#       3 warnings.filterwarnings('ignore')
#       5 #read zip geometry file
# ----> 6 zips = gpd.read_file('flatfiles/ZIP_CODE_040114.shp')
#       7 zips.head(10)
#       9 #get population, area info per zip, to build per-capita feats wrto the tree data
#
# File /opt/anaconda3/envs/cusp_python_3_9/lib/python3.9/site-packages/geopandas/io/file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File /opt/anaconda3/envs/cusp_python_3_9/lib/python3.9/site-packages/geopandas/io/file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
#     539         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     540         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     543         stacklevel=3,
#     544     )
#     545     kwargs["columns"] = kwargs.pop("include_fields")
# --> 547 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File /opt/anaconda3/envs/cusp_python_3_9/lib/python3.9/site-packages/pyogrio/geopandas.py:261, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     256 if not use_arrow:
#     257     # For arrow, datetimes are read as is.
#     258     # For numpy IO, datetimes are read as string values to preserve timezone info
#     259     # as numpy does not directly support timezones.
#     260     kwargs["datetime_as_string"] = True
# --> 261 result = read_func(
#     262     path_or_buffer,
#     263     layer=layer,
#     264     encoding=encoding,
#     265     columns=columns,
#     266     read_geometry=read_geometry,
#     267     force_2d=gdal_force_2d,
#     268     skip_features=skip_features,
#     269     max_features=max_features,
#     270     where=where,
#     271     bbox=bbox,
#     272     mask=mask,
#     273     fids=fids,
#     274     sql=sql,
#     275     sql_dialect=sql_dialect,
#     276     return_fids=fid_as_index,
#     277     **kwargs,
#     278 )
#     280 if use_arrow:
#     281     meta, table = result
#
# File /opt/anaconda3/envs/cusp_python_3_9/lib/python3.9/site-packages/pyogrio/raw.py:196, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      56 """Read OGR data source into numpy arrays.
#      57
#      58 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)
#     191
#     192 """
#     194 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 196 return ogr_read(
#     197     get_vsi_path_or_buffer(path_or_buffer),
#     198     layer=layer,
#     199     encoding=encoding,
#     200     columns=columns,
#     201     read_geometry=read_geometry,
#     202     force_2d=force_2d,
#     203     skip_features=skip_features,
#     204     max_features=max_features or 0,
#     205     where=where,
#     206     bbox=bbox,
#     207     mask=_mask_to_wkb(mask),
#     208     fids=fids,
#     209     sql=sql,
#     210     sql_dialect=sql_dialect,
#     211     return_fids=return_fids,
#     212     dataset_kwargs=dataset_kwargs,
#     213     datetime_as_string=datetime_as_string,
#     214 )
#
# File /opt/anaconda3/envs/cusp_python_3_9/lib/python3.9/site-packages/pyogrio/_io.pyx:1239, in pyogrio._io.ogr_read()
#
# File /opt/anaconda3/envs/cusp_python_3_9/lib/python3.9/site-packages/pyogrio/_io.pyx:219, in pyogrio._io.ogr_open()
#
# DataSourceError: Unable to open flatfiles/ZIP_CODE_040114.shx or flatfiles/ZIP_CODE_040114.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.

# %%
tree_zip_features_m['AREA']/43560
# Out:
# zipcode
# 83        879.269752
# 10001     408.515628
# 10002     603.308736
# 10003     356.712036
# 10004      91.885241
#             ...
# 11693      35.068851
# 11693     281.701481
# 11693      80.291914
# 11694    1104.260942
# 11697    1372.584036
# Name: AREA, Length: 198, dtype: float64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,3,figsize=(20,15),constrained_layout=False)
tree_zip_features_trunc.plot(
    column='tree_density (per acre)', 
    legend=True, 
    markersize=0.01,
    figsize=(10,10),
    scheme='Quantiles', 
    legend_kwds={'loc': 'upper left'},
    ax=ax[0]
)
ax[0].set_title('Tree Density Over NYC Zip (Trees per Acre)')
tree_zip_features_trunc.plot(
    column='trees_per_ppl', 
    legend=True, 
    markersize=0.01,
    figsize=(10,10),
    scheme='Quantiles', 
    legend_kwds={'loc': 'upper left'},
    ax=ax[1]
)
ax[1].set_title('Trees per Person Over NYC Zip')
tree_zip_features_trunc.plot(
    column='Tree Quality', 
    legend=True, 
    markersize=0.01,
    figsize=(10,10),
    scheme='Quantiles', 
    legend_kwds={'loc': 'upper left'},
    ax=ax[2]
)
ax[2].set_title('Tree Quality Score')
plt.savefig('treefeatures.png',)
plt.show()

# %%
tree_zip_features_trunc.to_csv('flatfiles/tree_features_final.csv')

# %%
tree_zip_features_trunc
# Out:
#          Tree Quality  trees_per_ppl  tree_density (per acre)  \
# zipcode
# 83           0.949571      37.280000                 1.059971
# 10001        0.845882       0.037924                 2.080704
# 10002        0.767377       0.026542                 3.576941
# 10003        0.761709       0.034772                 5.446971
# 10004        0.829060       0.053498                 1.273327
# ...               ...            ...                      ...
# 11693        0.511352       0.091658                28.886033
# 11693        0.511352       0.091658                 3.596005
# 11693        0.511352       0.091658                12.616463
# 11694        0.616499       0.157516                 2.876132
# 11697        0.000000       0.005884                 0.017485
#
#                                                   geometry
# zipcode
# 83       POLYGON ((998309.725 229616.681, 998282.853 22...
# 10001    POLYGON ((981958.647 213464.453, 981980.328 21...
# 10002    POLYGON ((991339.87 207576.784, 991330.49 2075...
# 10003    POLYGON ((989830.469 207048.126, 989716.354 20...
# 10004    POLYGON ((981197.409 196571.082, 981485.049 19...
# ...                                                    ...
# 11693    POLYGON ((1030722.649 160980.77, 1030642.283 1...
# 11693    POLYGON ((1036087.15 154632.639, 1036096.661 1...
# 11693    POLYGON ((1028453.995 167153.41, 1027813.01 16...
# 11694    POLYGON ((1034425.42 153503.826, 1034416.18 15...
# 11697    POLYGON ((1016691.78 146366.409, 1016655.757 1...
#
# [198 rows x 4 columns]

# %%
aq_url = 'https://data.cityofnewyork.us/resource/c3uy-2p5r.json'
params={'$limit':20000}
aq = pd.DataFrame(requests.get(aq_url, params = params).json(), )
aq.head(15)
# Out:
#    unique_id indicator_id                     name measure measure_info  \
# 0     827080          386               Ozone (O3)    Mean          ppb
# 1     827061          386               Ozone (O3)    Mean          ppb
# 2     827067          386               Ozone (O3)    Mean          ppb
# 3     827081          386               Ozone (O3)    Mean          ppb
# 4     825967          375   Nitrogen dioxide (NO2)    Mean          ppb
# 5     825985          375   Nitrogen dioxide (NO2)    Mean          ppb
# 6     827068          386               Ozone (O3)    Mean          ppb
# 7     825976          375   Nitrogen dioxide (NO2)    Mean          ppb
# 8     825933          375   Nitrogen dioxide (NO2)    Mean          ppb
# 9     827079          386               Ozone (O3)    Mean          ppb
# 10    823561          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 11    823214          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 12    826076          375   Nitrogen dioxide (NO2)    Mean          ppb
# 13    827063          386               Ozone (O3)    Mean          ppb
# 14    825831          375   Nitrogen dioxide (NO2)    Mean          ppb
#
#    geo_type_name geo_join_id                        geo_place_name  \
# 0          UHF34         104                  Pelham - Throgs Neck
# 1          UHF34         405              Ridgewood - Forest Hills
# 2          UHF34         302  Central Harlem - Morningside Heights
# 3          UHF34         103                    Fordham - Bronx Pk
# 4          UHF34         104                  Pelham - Throgs Neck
# 5          UHF42         502                Stapleton - St. George
# 6          UHF34         301                    Washington Heights
# 7          UHF34         101               Kingsbridge - Riverdale
# 8          UHF34         204                         East New York
# 9          UHF34         201                            Greenpoint
# 10            CD         412             Jamaica and Hollis (CD12)
# 11            CD         104             Clinton and Chelsea (CD4)
# 12            CD         414     Rockaway and Broad Channel (CD14)
# 13         UHF34         402                           West Queens
# 14            CD         107                 Upper West Side (CD7)
#
#     time_period               start_date data_value
# 0   Summer 2022  2022-06-01T00:00:00.000       33.3
# 1   Summer 2022  2022-06-01T00:00:00.000       34.2
# 2   Summer 2022  2022-06-01T00:00:00.000       30.9
# 3   Summer 2022  2022-06-01T00:00:00.000       31.7
# 4   Summer 2022  2022-06-01T00:00:00.000       12.0
# 5   Summer 2022  2022-06-01T00:00:00.000        8.7
# 6   Summer 2022  2022-06-01T00:00:00.000       29.9
# 7   Summer 2022  2022-06-01T00:00:00.000       10.6
# 8   Summer 2022  2022-06-01T00:00:00.000       10.9
# 9   Summer 2022  2022-06-01T00:00:00.000       32.4
# 10  Summer 2022  2022-06-01T00:00:00.000        6.3
# 11  Summer 2022  2022-06-01T00:00:00.000        8.0
# 12  Summer 2022  2022-06-01T00:00:00.000        6.9
# 13  Summer 2022  2022-06-01T00:00:00.000       33.6
# 14  Summer 2022  2022-06-01T00:00:00.000       14.7

# %%
aq['geo_type_name'].unique()
# Out:
# array(['UHF34', 'UHF42', 'CD', 'Borough', 'Citywide'], dtype=object)

# %%
aq['name'].unique()
# Out:
# array(['Ozone (O3)', 'Nitrogen dioxide (NO2)', 'Fine particles (PM 2.5)',
#        'Annual vehicle miles traveled (cars)',
#        'Annual vehicle miles traveled (trucks)',
#        'Annual vehicle miles traveled',
#        'Respiratory hospitalizations due to PM2.5 (age 20+)',
#        'Asthma emergency department visits due to PM2.5',
#        'Asthma emergency departments visits due to Ozone',
#        'Cardiovascular hospitalizations due to PM2.5 (age 40+)',
#        'Cardiac and respiratory deaths due to Ozone',
#        'Asthma hospitalizations due to Ozone', 'Deaths due to PM2.5',
#        'Boiler Emissions- Total PM2.5 Emissions',
#        'Boiler Emissions- Total SO2 Emissions',
#        'Boiler Emissions- Total NOx Emissions',
#        'Outdoor Air Toxics - Formaldehyde',
#        'Outdoor Air Toxics - Benzene'], dtype=object)

# %%
aq.loc[aq['geo_join_id']=='401'].head(10)
# Out:
#     unique_id indicator_id                     name measure measure_info  \
# 16     823397          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 80     825712          375   Nitrogen dioxide (NO2)    Mean          ppb
# 88     827115          386               Ozone (O3)    Mean          ppb
# 125    827006          386               Ozone (O3)    Mean          ppb
# 132    825897          375   Nitrogen dioxide (NO2)    Mean          ppb
# 133    826351          375   Nitrogen dioxide (NO2)    Mean          ppb
# 159    823241          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 179    823528          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 363    827064          386               Ozone (O3)    Mean          ppb
# 431    823240          365  Fine particles (PM 2.5)    Mean       mcg/m3
#
#     geo_type_name geo_join_id                      geo_place_name  \
# 16          UHF34         401          Long Island City - Astoria
# 80          UHF42         401          Long Island City - Astoria
# 88          UHF42         401          Long Island City - Astoria
# 125            CD         401  Long Island City and Astoria (CD1)
# 132         UHF34         401          Long Island City - Astoria
# 133            CD         401  Long Island City and Astoria (CD1)
# 159         UHF42         401          Long Island City - Astoria
# 179            CD         401  Long Island City and Astoria (CD1)
# 363         UHF34         401          Long Island City - Astoria
# 431         UHF42         401          Long Island City - Astoria
#
#              time_period               start_date data_value
# 16           Summer 2022  2022-06-01T00:00:00.000        7.2
# 80           Summer 2022  2022-06-01T00:00:00.000       13.2
# 88           Summer 2022  2022-06-01T00:00:00.000       32.9
# 125          Summer 2022  2022-06-01T00:00:00.000       33.6
# 132          Summer 2022  2022-06-01T00:00:00.000       13.2
# 133          Summer 2022  2022-06-01T00:00:00.000       12.0
# 159          Summer 2022  2022-06-01T00:00:00.000        7.2
# 179          Summer 2022  2022-06-01T00:00:00.000        7.0
# 363          Summer 2022  2022-06-01T00:00:00.000       32.9
# 431  Annual Average 2022  2022-01-01T00:00:00.000        6.4

# %%
tree_census_df.loc[tree_census_df['cb_num']==401]['nta_name'].unique()
# Out:
# array(['Steinway', 'Astoria', 'Old Astoria', 'Woodside',
#        'Queensbridge-Ravenswood-Long Island City',
#        'Hunters Point-Sunnyside-West Maspeth', 'Jackson Heights'],
#       dtype=object)

# %%
cb_join = tree_census_df[['cb_num','nta_name']].drop_duplicates()
cb_join['cb_num'] = cb_join['cb_num'].astype(str)
aq_cd = aq.loc[aq['geo_type_name']=='CD']
aq_cd[['geo_join_id', 'geo_place_name', 'geo_type_name']].merge(
    cb_join, 
    how='inner', 
    left_on='geo_join_id',
    right_on='cb_num'
).head(5)
# Out:
#   geo_join_id             geo_place_name geo_type_name cb_num       nta_name
# 0         412  Jamaica and Hollis (CD12)            CD    412     St. Albans
# 1         412  Jamaica and Hollis (CD12)            CD    412        Jamaica
# 2         412  Jamaica and Hollis (CD12)            CD    412         Hollis
# 3         412  Jamaica and Hollis (CD12)            CD    412   Baisley Park
# 4         412  Jamaica and Hollis (CD12)            CD    412  South Jamaica

# %% [markdown]
# ### By Community Board/District
#
# Needed in order to join with the carbon emissions dataset

# %%
#make analysis at zipcode level...
cb_grp = tree_census_tr.groupby(['cb_num']).agg(
    tree_count=('tree_id', len), 
    tree_size=('tree_dbh', np.sum)
)

#avg tree size (diameter)
cb_grp['tree_size'] = cb_grp['tree_size']/cb_grp['tree_count']

#count trees per zip/health category (good, fair, bad), then pivot on the health cats
cb_grp_health_status = tree_census_tr.groupby(['cb_num','health'])[['tree_id']].count().reset_index()
cb_grp_health_status_piv = cb_grp_health_status.pivot(
    index='cb_num',
    columns='health', 
    values='tree_id'
)

#concat cb features
cb_grp_health_status_piv = cb_grp_health_status_piv.div(cb_grp['tree_count'], axis=0)
tree_cb_features = pd.concat((cb_grp_health_status_piv,cb_grp),axis=1)
tree_cb_features.head(10)

tree_cb_features['Good'] = tree_cb_features['Good'].fillna(0.0)
tree_cb_features = tree_cb_features.rename(
    columns={
        'Good':'Tree Quality'
    }
)

tree_cb_features = tree_cb_features.reset_index()
tree_cb_features['cb_num'] = tree_cb_features['cb_num'].astype(str)

#pre-process aq dataset before merging...
aq_parse = aq.loc[
    (aq['geo_type_name'] == 'CD')
   &(
       (aq['name'].str.contains('Outdoor Air Toxics')) 
     | (aq['name'].str.contains('Boiler Emissions')) 
     | (
         (aq['name'] == 'Nitrogen dioxide (NO2)') 
       & (aq['time_period'] == 'Annual Average 2022')
       )
   )
]
aq_parse['data_value'] = aq_parse['data_value'].astype(np.float64)

combined_aq_tree_census = aq_parse.merge(
    tree_cb_features, 
    how='inner', 
    left_on='geo_join_id',
    right_on='cb_num'
)

combined_aq_tree_census
# Out:
#     unique_id indicator_id                               name  \
# 0      826349          375             Nitrogen dioxide (NO2)
# 1      825842          375             Nitrogen dioxide (NO2)
# 2      826337          375             Nitrogen dioxide (NO2)
# 3      826331          375             Nitrogen dioxide (NO2)
# 4      826002          375             Nitrogen dioxide (NO2)
# ..        ...          ...                                ...
# 172    227553          647  Outdoor Air Toxics - Formaldehyde
# 173    227530          647  Outdoor Air Toxics - Formaldehyde
# 174    227544          647  Outdoor Air Toxics - Formaldehyde
# 175    227562          647  Outdoor Air Toxics - Formaldehyde
# 176    227512          647  Outdoor Air Toxics - Formaldehyde
#
#                           measure measure_info geo_type_name geo_join_id  \
# 0                            Mean          ppb            CD         318
# 1                            Mean          ppb            CD         103
# 2                            Mean          ppb            CD         314
# 3                            Mean          ppb            CD         312
# 4                            Mean          ppb            CD         202
# ..                            ...          ...           ...         ...
# 172  Annual average concentration       Âµg/m3            CD         403
# 173  Annual average concentration       Âµg/m3            CD         210
# 174  Annual average concentration       Âµg/m3            CD         312
# 175  Annual average concentration       Âµg/m3            CD         412
# 176  Annual average concentration       Âµg/m3            CD         104
#
#                           geo_place_name          time_period  \
# 0          Flatlands and Canarsie (CD18)  Annual Average 2022
# 1    Lower East Side and Chinatown (CD3)  Annual Average 2022
# 2            Flatbush and Midwood (CD14)  Annual Average 2022
# 3                    Borough Park (CD12)  Annual Average 2022
# 4         Hunts Point and Longwood (CD2)  Annual Average 2022
# ..                                   ...                  ...
# 172                Jackson Heights (CD3)                 2011
# 173    Throgs Neck and Co-op City (CD10)                 2011
# 174                  Borough Park (CD12)                 2011
# 175            Jamaica and Hollis (CD12)                 2011
# 176            Clinton and Chelsea (CD4)                 2011
#
#                   start_date  data_value cb_num      Fair  Tree Quality  \
# 0    2022-01-01T00:00:00.000        13.3    318  0.141959      0.816994
# 1    2022-01-01T00:00:00.000        17.8    103  0.180293      0.764069
# 2    2022-01-01T00:00:00.000        14.7    314  0.146542      0.806324
# 3    2022-01-01T00:00:00.000        15.2    312  0.136094      0.828087
# 4    2022-01-01T00:00:00.000        18.1    202  0.130795      0.827946
# ..                       ...         ...    ...       ...           ...
# 172  2011-01-01T00:00:00.000         2.3    403  0.147843      0.810373
# 173  2011-01-01T00:00:00.000         2.0    210  0.095958      0.877063
# 174  2011-01-01T00:00:00.000         2.0    312  0.136094      0.828087
# 175  2011-01-01T00:00:00.000         1.8    412  0.098319      0.874420
# 176  2011-01-01T00:00:00.000         2.9    104  0.131025      0.824395
#
#          Poor  tree_count  tree_size
# 0    0.041048       18442  15.426852
# 1    0.055638        4709   8.449352
# 2    0.047134       10120  13.931423
# 3    0.035819       11977  12.864323
# 4    0.041259        4702   7.340706
# ..        ...         ...        ...
# 172  0.041784       10315  12.319341
# 173  0.026979       10786  11.491100
# 174  0.035819       11977  12.864323
# 175  0.027262       24980  13.073899
# 176  0.044580        4419   7.941163
#
# [177 rows x 17 columns]

# %%
combined_aq_tree_census[['name','measure','measure_info','time_period']].drop_duplicates()
# Out:
#                                  name                       measure  \
# 0              Nitrogen dioxide (NO2)                          Mean
# 59       Outdoor Air Toxics - Benzene  Annual average concentration
# 61  Outdoor Air Toxics - Formaldehyde  Annual average concentration
#
#    measure_info          time_period
# 0           ppb  Annual Average 2022
# 59       Âµg/m3                 2011
# 61       Âµg/m3                 2011

# %%
#read community board geojson, add geometries to aq/tree dataset
import matplotlib.pyplot as plt
cb_geometries = gpd.read_file("flatfiles/Community Districts.geojson")
combined_aq_tree_census_geoms = combined_aq_tree_census.merge(
    cb_geometries, 
    how='inner', 
    left_on='cb_num', 
    right_on='boro_cd'
)

#build tree density feature
combined_aq_tree_census_geoms.columns
combined_aq_tree_census_geoms['cb_acreage'] = \
combined_aq_tree_census_geoms['shape_area'].astype(np.float64)/43560
combined_aq_tree_census_geoms['Tree Density (per Acre)'] = \
combined_aq_tree_census_geoms['tree_count']/combined_aq_tree_census_geoms['cb_acreage']


combined_aq_tree_census_geoms['Tree Density (per Acre)'].hist(bins=50,)
plt.title('Tree Density (Community District)')
plt.show()

# %% [markdown]
# Run an analysis btw tree census features w/ pollution types (benzene, formaldehyde)

# %%
from scipy.stats import ks_1samp, norm


combined_trunc = combined_aq_tree_census_geoms[[
    'name','cb_num','Tree Quality','Tree Density (per Acre)', 'data_value', 'geometry'
]]
combined_trunc = combined_trunc.rename(
    columns={
        'name':'Pollution Category', 
        'data_value':'Pollution Concentration Value'
    }
)

features = [
    'Tree Quality', 'Tree Density (per Acre)'
]

fig,ax=plt.subplots(1,2,figsize=(15,10))
ax_feat_map = list(zip(ax, features))
for _ax, f in ax_feat_map:
   # norm_fit = ks_1samp(
    #    combined_trunc[f].drop_duplicates(), norm.cdf
  #  )
   # if norm_fit.pvalue < 0.05:
    #    print(f'Feature {f} not normally distributed')
    #else:
     #   print('Feature is potentially normally distributed')

    for p_type in combined_trunc['Pollution Category'].unique():
        d=combined_trunc.loc[combined_trunc['Pollution Category']==p_type]
        x = d[f]
        y = d['Pollution Concentration Value'] 
        y_std = (y - y.mean()) / y.std()
        corr = np.corrcoef(x,y)[0,1]
        print(f'r[{f},{p_type}] = {corr}')
        _ax.scatter(
            x=x, y=y_std,label=p_type
        )
    _ax.legend()
    _ax.set_xlabel(f)
    _ax.set_ylabel('Pollution Concentration Value [Standardized]')
    _ax.set_title(f'{f} vs Pollution Concentration by NYC Community District')
plt.show()

pollution_cat = combined_trunc.pivot(
    index='cb_num', 
    values='Pollution Concentration Value', 
    columns='Pollution Category'
)
combined_trunc = combined_trunc.drop(columns=['Pollution Category','Pollution Concentration Value'])
combined_trunc = combined_trunc.set_index('cb_num').drop_duplicates()
combined_trunc = pd.concat((pollution_cat, combined_trunc,),axis=1)
combined_trunc = gpd.GeoDataFrame(combined_trunc)
combined_trunc.head(10)

combined_trunc.to_csv('flatfiles/combined_tree_census_pollution.csv')



#fig_geo, ax_geo = plt.subplots(2,2,figsize=(20,15),constrained_layout=False)
#ax_feat_map_geo = list(zip(ax_geo, features))
#for _ax, f in ax_feat_map_geo: 
#pollution_cat
    
#combined_trunc.index.unique()
# Out:
# r[Tree Quality,Nitrogen dioxide (NO2)] = -0.26417078116686965
# r[Tree Quality,Outdoor Air Toxics - Benzene] = -0.4583146765645917
# r[Tree Quality,Outdoor Air Toxics - Formaldehyde] = -0.39795945934781846
# r[Tree Density (per Acre),Nitrogen dioxide (NO2)] = 0.17466844185260824
# r[Tree Density (per Acre),Outdoor Air Toxics - Benzene] = 0.18741307344091535
# r[Tree Density (per Acre),Outdoor Air Toxics - Formaldehyde] = 0.27565519225509805

# %%
norm.cdf
# Out:
# <bound method rv_continuous.cdf of <scipy.stats._continuous_distns.norm_gen object at 0x2b7a7a7c0>>

# %%
combined_trunc.head()
# Out:
#         Nitrogen dioxide (NO2)  Outdoor Air Toxics - Benzene  \
# cb_num
# 101                       21.0                           2.3
# 102                       20.2                           2.6
# 103                       17.8                           2.2
# 104                       21.4                           2.9
# 105                       25.5                           3.4
#
#         Outdoor Air Toxics - Formaldehyde  Tree Quality  \
# cb_num
# 101                                   2.5      0.764040
# 102                                   2.6      0.730602
# 103                                   2.5      0.764069
# 104                                   2.9      0.824395
# 105                                   3.0      0.673560
#
#         Tree Density (per Acre)  \
# cb_num
# 101                    2.399876
# 102                    5.580675
# 103                    4.375522
# 104                    3.903700
# 105                    2.020331
#
#                                                  geometry
# cb_num
# 101     MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...
# 102     MULTIPOLYGON (((-74.00915 40.7425, -74.00902 4...
# 103     MULTIPOLYGON (((-73.98878 40.73397, -73.98757 ...
# 104     MULTIPOLYGON (((-73.99394 40.77318, -73.9937 4...
# 105     MULTIPOLYGON (((-73.97301 40.76428, -73.97141 ...

# %%
import re 

combined_trunc.columns = [re.sub(r'[^a-zA-Z0-9\s]', ' ', i).replace(" ",'_') for i in combined_trunc.columns]
targets = combined_trunc.columns[0:3]
predictors = combined_trunc.columns[3:5]

_, ax_targets=plt.subplots(1,3,figsize=(20,20))
for f,_ax in list(zip(targets,ax_targets)):
    combined_trunc.plot(
        column=f, 
        legend=True, 
        markersize=0.01,
        figsize=(10,10),
        scheme='Quantiles', 
        legend_kwds={'loc': 'upper left'},
        ax=_ax
    )
    title_clean = f.replace('_',' ')
    _ax.set_title(title_clean)

_, ax_predictors=plt.subplots(1,2,figsize=(20,20))
for f,_ax in list(zip(predictors,ax_predictors)):
    combined_trunc.plot(
        column=f, 
        legend=True, 
        markersize=0.01,
        figsize=(10,10),
        scheme='Quantiles', 
        legend_kwds={'loc': 'upper left'},
        ax=_ax
    )
    title_clean = f.replace('_',' ')
    _ax.set_title(title_clean)

# %%
import statsmodels.formula.api as smf

alpha,pv_df = 0.05,[]
for t in targets:
    formula = f"{t} ~ {'+'.join(predictors)}"
    lm = smf.ols(formula = formula, data = combined_trunc).fit() 
    pv=pd.DataFrame(lm.pvalues,columns=[t])
    pv_df.append(pv)

    print(f'R2 [TARGET: {t}]: {lm.rsquared}')
   
pv_df = pd.concat(pv_df,axis=1)
pv_df
# Out:
# R2 [TARGET: Nitrogen_dioxide__NO2_]: 0.10060431102743861
# R2 [TARGET: Outdoor_Air_Toxics___Benzene]: 0.24575194266912181
# R2 [TARGET: Outdoor_Air_Toxics___Formaldehyde]: 0.23509219993730524
#                          Nitrogen_dioxide__NO2_  Outdoor_Air_Toxics___Benzene  \
# Intercept                              0.000012                      0.000002
# Tree_Quality                           0.041254                      0.000218
# Tree_Density__per_Acre_                0.171476                      0.109127
#
#                          Outdoor_Air_Toxics___Formaldehyde
# Intercept                                     2.772198e-08
# Tree_Quality                                  1.200310e-03
# Tree_Density__per_Acre_                       2.125869e-02

# %%
pv_df < alpha
# Out:
#                          Nitrogen_dioxide__NO2_  Outdoor_Air_Toxics___Benzene  \
# Intercept                                  True                          True
# Tree_Quality                               True                          True
# Tree_Density__per_Acre_                   False                         False
#
#                          Outdoor_Air_Toxics___Formaldehyde
# Intercept                                             True
# Tree_Quality                                          True
# Tree_Density__per_Acre_                               True
